# %% [markdown]
# # Домашнее задание
# Чем лучше бустить? Тестируем алгоритмы бустинга в бою.
#
# Цель:
# В этом домашнем задании вам предстоит провести детективную работу и узнать, какой же алгоритм бустинга работает лучше всего (конечно, применительно к конкретной задаче).

# %% [markdown]
# Выберите любой интересующий вас датасет по классификации или регрессии (можно взять из рекозитория https://archive.ics.uci.edu/ml/datasets.php, еще неплохие и востребованные на практике варианты - предсказание оттока пользователей https://www.kaggle.com/blastchar/telco-customer-churn или предсказание Customer Livetime Value (CLV или LTV) - https://www.kaggle.com/pankajjsh06/ibm-watson-marketing-customer-value-data

# %% [markdown]
# Data_for_UCI_named - electrical grid stability simulated data - смоделированные данные об устойчивости электрической сети

# %% [markdown]
# Attribute Information:
#
# 11 predictive attributes, 1 non-predictive(p1), 2 goal fields:
# 1. tau[x]: reaction time of participant (real from the range [0.5,10]s). Tau1 - the value for electricity producer.
# 2. p[x]: nominal power consumed(negative)/produced(positive)(real). For consumers from the range [-0.5,-2]s^-2; p1 = abs(p2 + p3 + p4)
# 3. g[x]: coefficient (gamma) proportional to price elasticity (real from the range [0.05,1]s^-1). g1 - the value for electricity producer.
# 4. stab: the maximal real part of the characteristic equation root (if positive - the system is linearly unstable)(real)
# 5. stabf: the stability label of the system (categorical: stable/unstable)

# %% [markdown]
# Информация об атрибутах:
#
# 11 прогностических атрибутов, 1 непрогностический (p1), 2 поля целей:
# 1. tau[x]: время реакции участника (реальное из диапазона [0,5,10] с). Tau1 - значение для производителя электроэнергии.
# 2. p[x]: номинальная потребляемая мощность (отрицательная)/вырабатываемая (положительная) (реальная). Для потребителей из диапазона [-0,5,-2]с^-2; р1 = абс (р2 + р3 + р4)
# 3. g[x]: коэффициент (гамма), пропорциональный ценовой эластичности (действительный из диапазона [0,05,1]с^-1). g1 - значение для производителя электроэнергии.
# 4. stab: максимальная действительная часть корня характеристического уравнения (если положительна - система линейно неустойчива)(real)
# 5. stabf: метка стабильности системы (категория: стабильная/нестабильная)

# %% [markdown]
# ## target = stabf: метка стабильности системы (категория: стабильная/нестабильная)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.model_selection import RandomizedSearchCV

import phik #https://towardsdatascience.com/phik-k-get-familiar-with-the-latest-correlation-coefficient-9ba0032b37e7

# %%
data = pd.read_csv('Data_for_UCI_named.csv')

# %%
df = data.copy() #скопирую data в переменую df, чтобы не подгружать data

# %%
# удалю stab т.к. делаю классификацию
df.drop(columns = 'stab', inplace = True)

# %%
df.head()
# Out:
#        tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0  2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1  9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2  8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3  0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4  3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
#
#          p4        g1        g2        g3        g4     stabf
# 0 -1.723086  0.650456  0.859578  0.887445  0.958034  unstable
# 1 -1.255012  0.413441  0.862414  0.562139  0.781760    stable
# 2 -0.920492  0.163041  0.766689  0.839444  0.109853  unstable
# 3 -0.997374  0.446209  0.976744  0.929381  0.362718  unstable
# 4 -0.554305  0.797110  0.455450  0.656947  0.820923  unstable

# %% [markdown]
# # Часть 1. EDA
# По выбранному датасету проведите EDA, познакомьтесь с признаками, посмотрите зависимости и т.д.

# %%
df.shape
# Out:
# (10000, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tau1    10000 non-null  float64
#  1   tau2    10000 non-null  float64
#  2   tau3    10000 non-null  float64
#  3   tau4    10000 non-null  float64
#  4   p1      10000 non-null  float64
#  5   p2      10000 non-null  float64
#  6   p3      10000 non-null  float64
#  7   p4      10000 non-null  float64
#  8   g1      10000 non-null  float64
#  9   g2      10000 non-null  float64
#  10  g3      10000 non-null  float64
#  11  g4      10000 non-null  float64
#  12  stabf   10000 non-null  object
# dtypes: float64(12), object(1)
# memory usage: 1015.8+ KB

# %%
df.describe()
# Out:
#                tau1          tau2          tau3          tau4            p1  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       5.250000      5.250001      5.250004      5.249997      3.750000
# std        2.742548      2.742549      2.742549      2.742556      0.752160
# min        0.500793      0.500141      0.500788      0.500473      1.582590
# 25%        2.874892      2.875140      2.875522      2.874950      3.218300
# 50%        5.250004      5.249981      5.249979      5.249734      3.751025
# 75%        7.624690      7.624893      7.624948      7.624838      4.282420
# max        9.999469      9.999837      9.999450      9.999443      5.864418
#
#                  p2            p3            p4            g1            g2  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      -1.250000     -1.250000     -1.250000      0.525000      0.525000
# std        0.433035      0.433035      0.433035      0.274256      0.274255
# min       -1.999891     -1.999945     -1.999926      0.050009      0.050053
# 25%       -1.624901     -1.625025     -1.624960      0.287521      0.287552
# 50%       -1.249966     -1.249974     -1.250007      0.525009      0.525003
# 75%       -0.874977     -0.875043     -0.875065      0.762435      0.762490
# max       -0.500108     -0.500072     -0.500025      0.999937      0.999944
#
#                  g3            g4
# count  10000.000000  10000.000000
# mean       0.525000      0.525000
# std        0.274255      0.274255
# min        0.050054      0.050028
# 25%        0.287514      0.287494
# 50%        0.525015      0.525002
# 75%        0.762440      0.762433
# max        0.999982      0.999930

# %%
#распределение stabf
stabf_freq = pd.concat([df['stabf'].value_counts(dropna=False).to_frame(name='stabf'), 
           df['stabf'].value_counts(dropna=False, normalize=True).to_frame(name='stabf%')], axis= 1)
stabf_freq
# Out:
#           stabf  stabf%
# unstable   6380   0.638
# stable     3620   0.362

# %% [markdown]
# ## Анализ переменных

# %%
# пропуки
print(df.isnull().sum())
print(f'всего пропусков: {df.isnull().sum().sum()}')
# Out:
# tau1     0
# tau2     0
# tau3     0
# tau4     0
# p1       0
# p2       0
# p3       0
# p4       0
# g1       0
# g2       0
# g3       0
# g4       0
# stabf    0
# dtype: int64
# всего пропусков: 0

# %% [markdown]
# ### Анализ столбцов

# %%
df.columns
# Out:
# Index(['tau1', 'tau2', 'tau3', 'tau4', 'p1', 'p2', 'p3', 'p4', 'g1', 'g2',
#        'g3', 'g4', 'stabf'],
#       dtype='object')

# %%
# колонки по типам
df.dtypes.value_counts()
# Out:
# float64    12
# object      1
# dtype: int64

# %%
#числовые, непрерывные переменныe
columns = df.select_dtypes(['float64']).columns
print(columns)
# Out:
# Index(['tau1', 'tau2', 'tau3', 'tau4', 'p1', 'p2', 'p3', 'p4', 'g1', 'g2',
#        'g3', 'g4'],
#       dtype='object')

# %%
# гистограммы и графики плотности распределения признаков для числовых, непрерывных переменных
# окружение для графиков, для каждой колонки два столбца
fig, axs = plt.subplots(nrows=len(columns), ncols=2, figsize=(10,30))

for index, column in enumerate(columns):
    # В первом столбце гистограмма
    sns.histplot(data=df, x=column, hue='stabf', ax=axs[index, 0])
    #df[column].hist(ax=axs[index, 0])
    axs[index, 0].set_title(f'Histogram: {column}', fontsize=12)
    axs[index, 0].set_ylabel('Count', fontsize=12)
        
    # Во втором столбце график сглаженной плотности распределения на основе ядерной оценки
    #df[column].plot(kind='kde', ax=axs[index, 1])
    sns.kdeplot(data=df, x=column, hue='stabf', ax=axs[index, 1])
    axs[index, 1].set_title(f'Kernel density estimate: {column}', fontsize=12)

plt.tight_layout(pad=3.0)
plt.show()

# %%
#Заменю stabf: метка стабильности системы (категория: stable = стабильная = 1/unstable = нестабильная = 0)
df.loc[df['stabf'] == 'stable', 'stabf'] = 1
df.loc[df['stabf'] == 'unstable', 'stabf'] = 0

# %%
df['stabf'] = df['stabf'].astype('int')

# %%
# проверю. распределение stabf
stabf_freq_encoder = pd.concat([df['stabf'].value_counts(dropna=False).to_frame(name='stabf'), 
           df['stabf'].value_counts(dropna=False, normalize=True).to_frame(name='stabf%')], axis= 1)
stabf_freq_encoder
# Out:
#    stabf  stabf%
# 0   6380   0.638
# 1   3620   0.362

# %%
stabf_freq
# Out:
#           stabf  stabf%
# unstable   6380   0.638
# stable     3620   0.362

# %% [markdown]
# #### stabf_freq = stabf_freq_encoder

# %%
corr_list = df.columns
corr_list
# Out:
# Index(['tau1', 'tau2', 'tau3', 'tau4', 'p1', 'p2', 'p3', 'p4', 'g1', 'g2',
#        'g3', 'g4', 'stabf'],
#       dtype='object')

# %%
#корреляции

corr = df[corr_list].corr()

# Отобразим ее на тепловой карте
plt.figure(figsize=(10,10));
sns.heatmap(corr, annot=True, fmt='.3f')
# Out:
# <AxesSubplot:>

# %%
phik_overview = df[corr_list].phik_matrix(interval_cols=corr_list)
plt.figure(figsize=(10,10));
sns.heatmap(phik_overview, annot=True, fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### На основе phik метода только 9 атрибутов из набора данных считаются важными или влиятельными для классификации, это следующие атрибуты: tau1	tau2	tau3	tau4	g1	g2	g3	g4

# %% [markdown]
# # Часть 2. Preprocessing & Feature Engineering

# %%
# оставлю tau1 tau2 tau3 tau4 g1 g2 g3 g4
drop_list = ['p1', 'p2', 'p3', 'p4']

# %%
df.drop(columns = drop_list, inplace=True)

# %%
# размерности
for el in df.columns:
    if el == 'stabf':
        continue
    else: 
        print(f'показатель: {el}')
        print(df.groupby('stabf')[el].agg(['mean', 'median', 'count']))
# Out:
# показатель: tau1
#            mean    median  count
# stabf
# 0      5.735239  5.848943   6380
# 1      4.394799  3.758877   3620
# показатель: tau2
#            mean    median  count
# stabf
# 0      5.758752  5.886590   6380
# 1      4.353362  3.715732   3620
# показатель: tau3
#            mean    median  count
# stabf
# 0      5.740601  5.870588   6380
# 1      4.385360  3.770857   3620
# показатель: tau4
#            mean    median  count
# stabf
# 0      5.744485  5.867834   6380
# 1      4.378495  3.796595   3620
# показатель: g1
#            mean    median  count
# stabf
# 0      0.565832  0.586484   6380
# 1      0.453035  0.425106   3620
# показатель: g2
#            mean    median  count
# stabf
# 0      0.569897  0.590298   6380
# 1      0.445872  0.407890   3620
# показатель: g3
#            mean    median  count
# stabf
# 0      0.572879  0.594452   6380
# 1      0.440618  0.404411   3620
# показатель: g4
#            mean    median  count
# stabf
# 0      0.567334  0.588503   6380
# 1      0.450390  0.418128   3620

# %% [markdown]
# #### размерности разные - буду приводить к одному масштабу

# %% [markdown]
# # Часть 3. Моделирование

# %%
#зафиксирую random_state
random_state=13

# %%
#Сохраним в  𝑋 все колонки признаки, а в  𝑦 − целевую переменную.
X = df.drop('stabf', axis=1)
y = df['stabf']

X.shape, y.shape
# Out:
# ((10000, 8), (10000,))

# %%
#Разобьем данные на тренировочный и тестовый наборы.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=random_state)

# %%
# метрики качества буду собирать в дата-фрейм df_metrics. Создам функцию

df_score = pd.DataFrame({"score":["Accuracy", "Precision", "Recall", "F1-score", "AUC"]})
df_score.set_index("score")

def get_df_score(classifier, y_expected, y_predicted, y_predicted_proba):
    accuracy = accuracy_score(y_predicted, y_expected)
    print("Accuracy:  {:.3f}".format(accuracy))

    precision = precision_score(y_predicted, y_expected)
    print("Precision: {:.3f}".format(precision))

    recall = recall_score(y_predicted, y_expected)
    print("Recall:    {:.3f}".format(recall))

    f1 = f1_score(y_predicted, y_expected)
    print("F1-score:  {:.3f}".format(f1))
    
    auc = roc_auc_score(y_expected, y_predicted_proba)
    print("AUC:       {:.3f}".format(auc))
    
    df_score[classifier] = [accuracy, precision, recall, f1, auc]

# %%
scaler_list = ['tau1', 'tau2', 'tau3', 'tau4', 'g1', 'g2', 'g3', 'g4']

# %%
#Приведу к одному масштабу непрерывные признаки
 
X_train_scaled = X_train.copy()
X_test_scaled = X_test.copy()

scaler = StandardScaler()
X_train_scaled[scaler_list] = scaler.fit_transform(X_train[scaler_list])
X_test_scaled[scaler_list] = scaler.transform(X_test[scaler_list])

# %% [markdown]
# ### Моделирование из коробки

# %%
# GradientBoostingClassifier
from sklearn.ensemble import GradientBoostingClassifier

gb_classifier = GradientBoostingClassifier()
gb_classifier.fit(X_train_scaled, y_train)
y_pred = gb_classifier.predict(X_test_scaled)
y_pred_proba = gb_classifier.predict_proba(X_test_scaled)
get_df_score('GradientBoostingClassifier', y_test, y_pred, y_pred_proba[:, 1])
# Out:
# Accuracy:  0.919
# Precision: 0.841
# Recall:    0.923
# F1-score:  0.880
# AUC:       0.977

# %%
# XGBoost

import xgboost as xgb

xgb_classifier = xgb.XGBClassifier()
xgb_classifier.fit(X_train_scaled, y_train)
y_pred = xgb_classifier.predict(X_test_scaled)
y_pred_proba = xgb_classifier.predict_proba(X_test_scaled)
get_df_score('XGBClassifier', y_test, y_pred, y_pred_proba[:, 1])
# Out:
# [02:54:32] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Users\smndy\anaconda3\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# C:\Users\smndy\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# Accuracy:  0.942
# Precision: 0.900
# Recall:    0.932
# F1-score:  0.916
# AUC:       0.988

# %%
#CatBoost
from catboost import CatBoostClassifier

catboost_classifier = CatBoostClassifier(silent=True)
catboost_classifier.fit(X_train_scaled, y_train)
y_pred = catboost_classifier.predict(X_test_scaled)
y_pred_proba = catboost_classifier.predict_proba(X_test_scaled)
get_df_score('CatBoostClassifier', y_test, y_pred, y_pred_proba[:, 1])
# Out:
# Accuracy:  0.951
# Precision: 0.913
# Recall:    0.947
# F1-score:  0.929
# AUC:       0.992

# %%
#LGBMClassifier

from lightgbm import LGBMClassifier

lgbm_classifier = LGBMClassifier()
lgbm_classifier.fit(X_train_scaled, y_train)
y_pred = lgbm_classifier.predict(X_test_scaled)
y_pred_proba = lgbm_classifier.predict_proba(X_test_scaled)
get_df_score('LGBMClassifier', y_test, y_pred, y_pred_proba[:, 1])
# Out:
# Accuracy:  0.934
# Precision: 0.880
# Recall:    0.930
# F1-score:  0.904
# AUC:       0.987

# %%
#Результаты
df_score_base = df_score.copy()
df_score_base
# Out:
#        score  GradientBoostingClassifier  XGBClassifier  CatBoostClassifier  \
# 0   Accuracy                    0.919333       0.942000            0.951333
# 1  Precision                    0.840607       0.900380            0.912713
# 2     Recall                    0.922917       0.932220            0.946850
# 3   F1-score                    0.879841       0.916023            0.929469
# 4        AUC                    0.977112       0.988153            0.992064
#
#    LGBMClassifier
# 0        0.934333
# 1        0.879507
# 2        0.929789
# 3        0.903949
# 4        0.987084

# %% [markdown]
# #### На данный момент наибольшую точность прогнозирования дает CatBoostClassifier

# %% [markdown]
# ### Моделирование с настройкой гиперпараметров

# %%
#GradientBoostingClassifier
parameters = {
    "n_estimators": stats.randint(10, 1000),
    "learning_rate": stats.uniform(0.01, 1),
    "subsample": stats.uniform(0.5, 1.0),

    "max_depth": stats.randint(3, 10),
    "min_samples_split": stats.randint(3, 20),
    "min_samples_leaf": stats.randint(3, 20)
}

gb_classifier_tuned = RandomizedSearchCV(GradientBoostingClassifier(), parameters, n_iter=100, cv=5, n_jobs=-1)
gb_classifier_tuned.fit(X_train_scaled, y_train)

print(gb_classifier_tuned.score(X_train_scaled, y_train))
print(gb_classifier_tuned.best_params_)
# Out:
# C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 260 fits failed out of a total of 500.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.0394211644656917
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.0747406028138462
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.1697213395512605
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.3411798505354844
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.1125850849847274
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.3769714019110104
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.4445393638351627
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.4876378424463796
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.2243537985029862
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.152787453324107
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.4071820340388936
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.4254246669422073
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.2138852019747306
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.282597790047039
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.4806112142814314
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.4517072373394804
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.1163164879312966
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.3271923259909555
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.1220961357635506
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.418838063387501
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.3889679133406234
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.40998677173522
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.1885361429800996
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.0689741174841996
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.1826060442601816
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.2641651025910479
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.019847816764524
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.3550734378169955
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.414331515229481
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.3207705627872528
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.0086265392155447
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.312238068893121
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.4314694716310585
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.4666190140601647
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.172252450730489
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.1375099625861842
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.142096020378071
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.303145620390513
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.077576005287922
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.161461455587729
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.2854912957378688
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.0390575169179885
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.1633318634163943
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.1691931726338094
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.465676037610015
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.4318345485797206
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.294792653928992
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.425355923329749
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.4553139825473616
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.320202896383372
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.2405729312142089
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 525, in fit
#     self._check_params()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 317, in _check_params
#     raise ValueError("subsample must be in (0,1] but was %r" % self.subsample)
# ValueError: subsample must be in (0,1] but was 1.1902055718694204
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [0.94714286 0.941      0.94785714 0.92071429        nan        nan
#         nan 0.94228571 0.94328571        nan        nan        nan
#         nan        nan        nan 0.93471429        nan        nan
#  0.945      0.93357143        nan 0.943      0.94142857 0.79071429
#  0.94628571 0.93942857        nan 0.94414286        nan        nan
#         nan 0.91928571 0.941             nan        nan        nan
#         nan 0.91357143        nan 0.93              nan        nan
#  0.94828571        nan        nan 0.94657143 0.94871429 0.94342857
#         nan 0.94542857        nan 0.94785714 0.94157143 0.90371429
#  0.93928571        nan        nan        nan 0.90771429        nan
#         nan 0.92257143        nan 0.93828571        nan        nan
#         nan 0.94942857        nan 0.92742857        nan        nan
#  0.94114286        nan        nan 0.944      0.94671429        nan
#         nan        nan        nan        nan 0.93871429        nan
#  0.94       0.94414286        nan        nan 0.94428571 0.94542857
#  0.94014286 0.941      0.94557143 0.92085714 0.94014286        nan
#         nan 0.89971429 0.93871429        nan]
#   warnings.warn(
# 1.0
# {'learning_rate': 0.0652773644008424, 'max_depth': 6, 'min_samples_leaf': 10, 'min_samples_split': 16, 'n_estimators': 835, 'subsample': 0.7113465336322092}

# %%
#GradientBoostingClassifier get_df_score
y_pred = gb_classifier_tuned.predict(X_test_scaled)
y_pred_proba = gb_classifier_tuned.predict_proba(X_test_scaled)
get_df_score('GradientBoostingClassifier_Tuned', y_test, y_pred, y_pred_proba[:, 1])
# Out:
# Accuracy:  0.945
# Precision: 0.898
# Recall:    0.941
# F1-score:  0.919
# AUC:       0.990

# %%
#XGBoost
parameters = {
    'n_estimators': stats.randint(10, 1000),
    'learning_rate': stats.uniform(0.01, 1),
    'subsample': stats.uniform(0.5, 1.0),

    'max_depth': stats.randint(3, 10),
    'gamma': stats.uniform (1, 9),
    'min_child_weight' : stats.randint(0, 10),
    'colsample_bytree': stats.uniform(0.5, 1),
    'reg_alpha': stats.randint(0, 1),
    'reg_lambda': stats.uniform(0, 1),
}

xgb_classifier_tuned = RandomizedSearchCV(xgb.XGBClassifier(), parameters, n_iter=100, cv=5, n_jobs=-1)
xgb_classifier_tuned.fit(X_train_scaled, y_train)

print(xgb_classifier_tuned.score(X_train_scaled, y_train))
print(xgb_classifier_tuned.best_params_)
# Out:
# C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 410 fits failed out of a total of 500.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.22129 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.14894 for Parameter subsample exceed bound [0,1]
# subsample: Row subsample ratio of training instance.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.42608 for Parameter subsample exceed bound [0,1]
# subsample: Row subsample ratio of training instance.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.26532 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.29323 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.01045 for Parameter subsample exceed bound [0,1]
# subsample: Row subsample ratio of training instance.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.19953 for Parameter subsample exceed bound [0,1]
# subsample: Row subsample ratio of training instance.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.20367 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.19497 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.05069 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.38639 for Parameter subsample exceed bound [0,1]
# subsample: Row subsample ratio of training instance.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.39819 for Parameter subsample exceed bound [0,1]
# subsample: Row subsample ratio of training instance.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.15132 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.32927 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.33277 for Parameter subsample exceed bound [0,1]
# subsample: Row subsample ratio of training instance.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.13438 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.20669 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.12926 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.38301 for Parameter subsample exceed bound [0,1]
# subsample: Row subsample ratio of training instance.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.39113 for Parameter subsample exceed bound [0,1]
# subsample: Row subsample ratio of training instance.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.42712 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.06331 for Parameter subsample exceed bound [0,1]
# subsample: Row subsample ratio of training instance.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.22483 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.08263 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.26036 for Parameter subsample exceed bound [0,1]
# subsample: Row subsample ratio of training instance.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.26733 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.3156 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.45827 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.49472 for Parameter subsample exceed bound [0,1]
# subsample: Row subsample ratio of training instance.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.3241 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.4443 for Parameter subsample exceed bound [0,1]
# subsample: Row subsample ratio of training instance.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.07896 for Parameter subsample exceed bound [0,1]
# subsample: Row subsample ratio of training instance.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.15323 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.30824 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.17767 for Parameter subsample exceed bound [0,1]
# subsample: Row subsample ratio of training instance.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.3002 for Parameter subsample exceed bound [0,1]
# subsample: Row subsample ratio of training instance.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.1267 for Parameter subsample exceed bound [0,1]
# subsample: Row subsample ratio of training instance.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
# ...
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.03057 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.31838 for Parameter subsample exceed bound [0,1]
# subsample: Row subsample ratio of training instance.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.12521 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.34989 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.18679 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.49658 for Parameter subsample exceed bound [0,1]
# subsample: Row subsample ratio of training instance.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.4798 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.41484 for Parameter subsample exceed bound [0,1]
# subsample: Row subsample ratio of training instance.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.27397 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.24215 for Parameter colsample_bytree exceed bound [0,1]
# colsample_bytree: Subsample ratio of columns, resample on each tree construction.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py", line 1250, in fit
#     self._Booster = train(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 188, in train
#     bst = _train_internal(params, dtrain,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\training.py", line 81, in _train_internal
#     bst.update(dtrain, i, obj)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 1680, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\xgboost\core.py", line 218, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: value 1.07276 for Parameter subsample exceed bound [0,1]
# subsample: Row subsample ratio of training instance.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.92242857        nan        nan
#         nan        nan        nan        nan        nan 0.94171429
#  0.93557143        nan 0.942      0.93457143        nan        nan
#  0.932             nan 0.934             nan 0.94471429        nan
#  0.93228571        nan 0.92914286        nan        nan        nan
#  0.93928571        nan        nan        nan        nan        nan
#         nan 0.939             nan        nan        nan        nan
#  0.92128571        nan        nan        nan        nan        nan
#  0.92171429        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan 0.94942857        nan 0.9               nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan 0.94771429        nan
#         nan        nan        nan        nan        nan        nan
#  0.94              nan        nan        nan]
#   warnings.warn(
# C:\Users\smndy\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# C:\Users\smndy\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [03:18:21] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0.9955714285714286
# {'colsample_bytree': 0.8916813143598864, 'gamma': 3.009636653765269, 'learning_rate': 0.21744700670393646, 'max_depth': 4, 'min_child_weight': 0, 'n_estimators': 410, 'reg_alpha': 0, 'reg_lambda': 0.8784545934385926, 'subsample': 0.6126104123760862}

# %%
#XGBoost get_df_score
y_pred = xgb_classifier_tuned.predict(X_test_scaled)
y_pred_proba = xgb_classifier_tuned.predict_proba(X_test_scaled)
get_df_score('XGBClassifier_Tuned', y_test, y_pred, y_pred_proba[:, 1])
# Out:
# Accuracy:  0.945
# Precision: 0.913
# Recall:    0.930
# F1-score:  0.921
# AUC:       0.990

# %%
#CatBoost
parameters = {
    'n_estimators': stats.randint(100, 1000),
    'learning_rate': stats.uniform(0.01, 0.1),
    'subsample': stats.uniform(0.5, 0.9),

    'depth': stats.randint(3, 13),
    "min_data_in_leaf": stats.randint(1, 10),    
    'l2_leaf_reg': stats.randint(1, 5),
    'random_strength': stats.uniform(0, 3),
    'bagging_temperature': stats.uniform(0.5, 1.0),
    'border_count': [32, 64, 128, 256]
}

catboost_classifier_tuned = RandomizedSearchCV(CatBoostClassifier(silent=True), parameters, 
                                               cv=5, n_jobs=-1)
catboost_classifier_tuned.fit(X_train_scaled, y_train)

print(catboost_classifier_tuned.score(X_train_scaled, y_train))
print(catboost_classifier_tuned.best_params_)
# Out:
# C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 10 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\catboost\core.py", line 5128, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\catboost\core.py", line 2339, in _fit
#     train_params = self._prepare_train_params(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\catboost\core.py", line 2266, in _prepare_train_params
#     _check_train_params(params)
#   File "_catboost.pyx", line 6080, in _catboost._check_train_params
#   File "_catboost.pyx", line 6099, in _catboost._check_train_params
# _catboost.CatBoostError: C:/Program Files (x86)/Go Agent/pipelines/BuildMaster/catboost.git/catboost/private/libs/options/bootstrap_options.cpp:5: Taken fraction should be in (0,1]
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [0.95242857        nan 0.95528571 0.95557143 0.95328571 0.94914286
#         nan 0.95214286 0.94528571 0.94785714]
#   warnings.warn(
# 0.9997142857142857
# {'bagging_temperature': 0.8971887532417149, 'border_count': 128, 'depth': 6, 'l2_leaf_reg': 3, 'learning_rate': 0.1023821321592272, 'min_data_in_leaf': 5, 'n_estimators': 252, 'random_strength': 1.5338552362978206, 'subsample': 0.5785938901519824}

# %%
#CatBoost get_df_score
y_pred = catboost_classifier_tuned.predict(X_test_scaled)
y_pred_proba = catboost_classifier_tuned.predict_proba(X_test_scaled)
get_df_score('CatBoostClassifier_Tuned', y_test, y_pred, y_pred_proba[:, 1])
# Out:
# Accuracy:  0.955
# Precision: 0.923
# Recall:    0.947
# F1-score:  0.935
# AUC:       0.992

# %%
#LGBMClassifier
parameters = {
    "n_estimators": stats.randint(10, 100),
    "learning_rate": stats.uniform(0.01, 1),
    "subsample": stats.uniform(0.5, 1.0),
    
    "max_depth": stats.randint(3, 13),
    "num_leaves": stats.randint(1, 50),
    "min_data_in_leaf": stats.randint(1, 100),    
    "max_bin": stats.randint(3, 50),    
    "boosting_type" : ['gbdt', 'dart'],    
    'reg_alpha': stats.randint(0, 4),
    'reg_lambda': stats.uniform(0, 4)
}

lgbm_classifier_tuned = RandomizedSearchCV(LGBMClassifier(), parameters, n_iter=1000,
                                            scoring='accuracy', cv=5, n_jobs=-1)
lgbm_classifier_tuned.fit(X_train_scaled, y_train)

print(lgbm_classifier_tuned.score(X_train_scaled, y_train))
print(lgbm_classifier_tuned.best_params_)
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set=91, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=91
# 0.9985714285714286
# {'boosting_type': 'gbdt', 'learning_rate': 0.4518274844888982, 'max_bin': 40, 'max_depth': 6, 'min_data_in_leaf': 91, 'n_estimators': 97, 'num_leaves': 23, 'reg_alpha': 3, 'reg_lambda': 0.9380719492520679, 'subsample': 0.6296565289542502}
# C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2595 fits failed out of a total of 5000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2455 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\lightgbm\sklearn.py", line 890, in fit
#     super().fit(X, _y, sample_weight=sample_weight, init_score=init_score, eval_set=valid_sets,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\lightgbm\sklearn.py", line 683, in fit
#     self._Booster = train(params, train_set,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\lightgbm\engine.py", line 228, in train
#     booster = Booster(params=params, train_set=train_set)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\lightgbm\basic.py", line 2229, in __init__
#     train_set.construct()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\lightgbm\basic.py", line 1468, in construct
#     self._lazy_init(self.data, label=self.label,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\lightgbm\basic.py", line 1270, in _lazy_init
#     self.__init_from_np2d(data, params_str, ref_dataset)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\lightgbm\basic.py", line 1312, in __init_from_np2d
#     _safe_call(_LIB.LGBM_DatasetCreateFromMat(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\lightgbm\basic.py", line 110, in _safe_call
#     raise LightGBMError(_LIB.LGBM_GetLastError().decode('utf-8'))
# lightgbm.basic.LightGBMError: Check failed: (bagging_fraction) <= (1.0) at c:\users\builder\appdata\local\temp\pip-req-build-zpa7v636\compile\src\io\config_auto.cpp, line 347 .
#
#
# --------------------------------------------------------------------------------
# 140 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\lightgbm\sklearn.py", line 890, in fit
#     super().fit(X, _y, sample_weight=sample_weight, init_score=init_score, eval_set=valid_sets,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\lightgbm\sklearn.py", line 683, in fit
#     self._Booster = train(params, train_set,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\lightgbm\engine.py", line 228, in train
#     booster = Booster(params=params, train_set=train_set)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\lightgbm\basic.py", line 2229, in __init__
#     train_set.construct()
#   File "C:\Users\smndy\anaconda3\lib\site-packages\lightgbm\basic.py", line 1468, in construct
#     self._lazy_init(self.data, label=self.label,
#   File "C:\Users\smndy\anaconda3\lib\site-packages\lightgbm\basic.py", line 1270, in _lazy_init
#     self.__init_from_np2d(data, params_str, ref_dataset)
#   File "C:\Users\smndy\anaconda3\lib\site-packages\lightgbm\basic.py", line 1312, in __init_from_np2d
#     _safe_call(_LIB.LGBM_DatasetCreateFromMat(
#   File "C:\Users\smndy\anaconda3\lib\site-packages\lightgbm\basic.py", line 110, in _safe_call
#     raise LightGBMError(_LIB.LGBM_GetLastError().decode('utf-8'))
# lightgbm.basic.LightGBMError: Check failed: (num_leaves) > (1) at c:\users\builder\appdata\local\temp\pip-req-build-zpa7v636\compile\src\io\config_auto.cpp, line 324 .
#
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\smndy\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [       nan 0.91957143 0.94157143 0.93128571 0.903      0.92971429
#         nan 0.89028571 0.92057143 0.92171429        nan        nan
#  0.94471429 0.93428571        nan 0.94057143        nan 0.93957143
#  0.94014286        nan        nan        nan 0.93814286 0.88057143
#  0.78128571        nan        nan        nan        nan 0.89571429
#         nan 0.94328571 0.93814286        nan        nan 0.93571429
#         nan 0.93285714        nan        nan 0.94428571 0.911
#         nan 0.77842857 0.92785714 0.92828571 0.90057143 0.83914286
#         nan        nan        nan        nan        nan        nan
#  0.93842857        nan 0.90928571        nan 0.903             nan
#         nan 0.94242857        nan 0.83214286        nan 0.94428571
#         nan 0.93285714        nan        nan        nan 0.93057143
#  0.93071429        nan 0.91585714        nan 0.94742857        nan
#  0.92557143 0.94314286 0.90914286        nan 0.92957143        nan
#  0.78042857        nan        nan        nan 0.94357143 0.94642857
#         nan        nan        nan        nan 0.92842857 0.89671429
#         nan 0.931             nan 0.941             nan        nan
#         nan 0.92642857 0.93085714        nan 0.77757143        nan
#  0.93557143        nan        nan        nan        nan 0.932
#  0.922      0.84357143        nan 0.90457143 0.91471429 0.92557143
#         nan        nan        nan        nan        nan 0.90157143
#         nan 0.93942857        nan        nan        nan        nan
#  0.91814286 0.93371429 0.89157143 0.93642857 0.78028571        nan
#         nan 0.93871429 0.94085714 0.935             nan 0.92871429
#         nan        nan 0.93014286 0.818      0.93128571        nan
#         nan        nan        nan        nan        nan        nan
#  0.94657143        nan 0.92114286 0.924             nan 0.91742857
#  0.94028571 0.935             nan 0.94128571 0.92728571 0.85071429
#         nan        nan 0.91328571        nan        nan 0.91971429
#         nan        nan 0.92271429 0.93671429        nan        nan
#  0.94657143        nan        nan        nan        nan        nan
#         nan 0.92228571 0.93757143 0.836      0.92971429 0.93642857
#  0.92957143        nan 0.94142857 0.94671429 0.65785714 0.94257143
#  0.93728571        nan        nan        nan 0.935      0.93871429
#         nan        nan        nan 0.93              nan 0.935
#         nan        nan        nan        nan        nan 0.92514286
#  0.92942857        nan        nan 0.93514286        nan        nan
#         nan 0.846      0.94028571        nan 0.917      0.93371429
#         nan 0.88728571        nan        nan 0.91457143 0.92785714
#  0.92528571        nan        nan 0.943      0.908             nan
#  0.92671429 0.93285714        nan        nan 0.91257143 0.92
#  0.906      0.86528571        nan 0.94385714 0.93171429        nan
#         nan 0.92457143        nan 0.91171429        nan        nan
#         nan 0.91       0.93157143 0.93828571 0.93071429 0.89257143
#  0.931      0.93185714 0.90928571        nan        nan 0.929
#         nan 0.94057143 0.93785714 0.93857143        nan 0.83885714
#         nan 0.93985714 0.89385714 0.93557143 0.92285714        nan
#  0.84271429 0.922      0.92385714 0.93614286        nan        nan
#  0.93114286 0.93628571 0.78142857 0.93414286        nan 0.914
#         nan        nan        nan        nan 0.93985714 0.93142857
#  0.94528571 0.93028571        nan 0.94071429 0.94471429        nan
#         nan        nan        nan 0.81857143        nan 0.63342857
#         nan        nan 0.94485714        nan        nan 0.94214286
#  0.91385714        nan        nan 0.92857143        nan        nan
#         nan 0.89157143 0.90771429 0.93971429        nan 0.93071429
#  0.89114286        nan 0.93157143        nan        nan        nan
#  0.94042857        nan        nan        nan]
#   warnings.warn(

# %%
y_pred = lgbm_classifier_tuned.predict(X_test_scaled)
y_pred_proba = lgbm_classifier_tuned.predict_proba(X_test_scaled)
get_df_score('LGBMClassifier_Tuned', y_test, y_pred, y_pred_proba[:, 1])
# Out:
# Accuracy:  0.947
# Precision: 0.912
# Recall:    0.935
# F1-score:  0.923
# AUC:       0.990

# %%
#Результаты
df_score_tuned = df_score.copy()
df_score_tuned.T
# Out:
#                                          0          1         2         3  \
# score                             Accuracy  Precision    Recall  F1-score
# GradientBoostingClassifier        0.919333   0.840607  0.922917  0.879841
# XGBClassifier                        0.942    0.90038   0.93222  0.916023
# CatBoostClassifier                0.951333   0.912713   0.94685  0.929469
# LGBMClassifier                    0.934333   0.879507  0.929789  0.903949
# GradientBoostingClassifier_Tuned  0.944667   0.898482  0.941352  0.919417
# XGBClassifier_Tuned               0.945333   0.912713  0.930368  0.921456
# CatBoostClassifier_Tuned             0.955    0.92315   0.94742  0.935127
# LGBMClassifier_Tuned              0.946667   0.911765  0.934825  0.923151
#
#                                          4
# score                                  AUC
# GradientBoostingClassifier        0.977112
# XGBClassifier                     0.988153
# CatBoostClassifier                0.992064
# LGBMClassifier                    0.987084
# GradientBoostingClassifier_Tuned  0.989934
# XGBClassifier_Tuned               0.989682
# CatBoostClassifier_Tuned          0.992292
# LGBMClassifier_Tuned               0.99013

# %% [markdown]
# # Вывод лучшая модель: CatBoostClassifier_Tuned
